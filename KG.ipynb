# %%
from scipy.stats import beta
import numpy as np
from np.
import collections
import time

def I(a, b):
    return beta.cdf(1/2, a, b)

def h(x):
    return max(x, 1 - x)

def R1(a, b):
    return h(I(a + 1, b)) - h(I(a, b))

def R2(a, b):
    return h(I(a, b + 1)) - h(I(a, b))

def KG_score(a, b):
    return a / (a + b) * R1(a, b) + b / (a + b) * R2(a, b)

def KG_policy(T, alpha):
    return Priority_policy(T=T, score=KG_score, alpha=alpha, initial=collections.defaultdict(float, {(0, 0): 1.0}))

# %%
def reward(a, b):
    if a < b:
        return beta.cdf(1/2, a + 1, b + 1)
    return 1 - beta.cdf(1/2, a + 1, b + 1)

def simulate(T, alpha, N, M, score):
    state_score = {(i, j): score(i + 1, j + 1) for i in range(T + 1) for j in range(T + 1)}
    start = time.time()
    rewards = []
    for _ in range(M):
        curr_state = {(0, 0): N}
        for __ in range(T):
            next_state = collections.defaultdict(int)
            budget = int(alpha * N)
            sorted_state = sorted(curr_state.keys(), key=lambda x: state_score[x], reverse=True)
            for s in sorted_state:
                pulled = min(curr_state[s], budget)
                budget = budget - pulled
                a, b = s
                tmp = np.random.binomial(pulled, (a + 1) / (a + b + 2))
                next_state[(a + 1, b)] += tmp
                next_state[(a, b + 1)] += pulled - tmp
                next_state[(a, b)] += curr_state[s] - pulled
            curr_state = next_state
        rewards.append(sum([curr_state[s] * reward(s[0], s[1]) for s in curr_state]))
    end = time.time()
    mean, std = np.mean(rewards), np.std(rewards) / np.sqrt(M)
    return mean, std


def simulate_benchmark(T, alpha, N, M):
    start = time.time()
    rewards = []
    for _ in range(M):
        curr_state = {(0, 0): N}
        for __ in range(T):
            next_state = collections.defaultdict(int)
            budget = int(alpha * N)
            sorted_state = curr_state.keys()
            for s in sorted_state:
                pulled = min(curr_state[s], budget)
                budget = budget - pulled
                a, b = s
                tmp = np.random.binomial(pulled, (a + 1) / (a + b + 2))
                next_state[(a + 1, b)] += tmp
                next_state[(a, b + 1)] += pulled - tmp
                next_state[(a, b)] += curr_state[s] - pulled
            curr_state = next_state
        rewards.append(sum([curr_state[s] * reward(s[0], s[1]) for s in curr_state]))
    end = time.time()
    mean, std = np.mean(rewards), np.std(rewards) / np.sqrt(M)
    return mean, std

# %%
cProfile.run("simulate_benchmark(T=6, alpha=1/4, N=100, M=400)")
# Out:
#          2478842 function calls (2344442 primitive calls) in 3.774 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     11200    0.011    0.000    0.215    0.000 <__array_function__ internals>:2(any)
#     11200    0.011    0.000    0.174    0.000 <__array_function__ internals>:2(atleast_1d)
#     33600    0.038    0.000    1.027    0.000 <__array_function__ internals>:2(extract)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(mean)
#     33600    0.026    0.000    0.143    0.000 <__array_function__ internals>:2(nonzero)
#     33600    0.034    0.000    0.249    0.000 <__array_function__ internals>:2(place)
#     67200    0.052    0.000    0.428    0.000 <__array_function__ internals>:2(ravel)
#     11200    0.014    0.000    0.051    0.000 <__array_function__ internals>:2(shape)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(std)
#     33600    0.028    0.000    0.215    0.000 <__array_function__ internals>:2(take)
#     11200    0.047    0.000    3.523    0.000 <ipython-input-25-1b8dd97bf56d>:1(reward)
#         1    0.075    0.075    3.774    3.774 <ipython-input-25-1b8dd97bf56d>:31(simulate_benchmark)
#       400    0.029    0.000    3.552    0.009 <ipython-input-25-1b8dd97bf56d>:49(<listcomp>)
#         1    0.000    0.000    3.774    3.774 <string>:1(<module>)
#     11200    0.003    0.000    0.003    0.000 <string>:2(_parse_args)
#    100800    0.037    0.000    0.189    0.000 _asarray.py:16(asarray)
#    100803    0.038    0.000    0.138    0.000 _asarray.py:88(asanyarray)
#     11200    0.116    0.000    0.116    0.000 _continuous_distns.py:527(_cdf)
#     11200    0.574    0.000    3.476    0.000 _distn_infrastructure.py:1797(cdf)
#     11200    0.099    0.000    1.526    0.000 _distn_infrastructure.py:520(argsreduce)
#     11200    0.223    0.000    1.250    0.000 _distn_infrastructure.py:545(<listcomp>)
#     11200    0.190    0.000    0.207    0.000 _distn_infrastructure.py:864(_argcheck)
#     22400    0.008    0.000    0.008    0.000 _distn_infrastructure.py:876(_get_support)
#     11200    0.061    0.000    0.065    0.000 _distn_infrastructure.py:901(_open_support_mask)
#         1    0.000    0.000    0.000    0.000 _methods.py:134(_mean)
#         1    0.000    0.000    0.000    0.000 _methods.py:167(_var)
#         1    0.000    0.000    0.000    0.000 _methods.py:215(_std)
#     11200    0.006    0.000    0.078    0.000 _methods.py:44(_any)
#         2    0.000    0.000    0.000    0.000 _methods.py:50(_count_reduce_items)
#     67200    0.011    0.000    0.011    0.000 fromnumeric.py:1689(_ravel_dispatcher)
#     67200    0.086    0.000    0.292    0.000 fromnumeric.py:1693(ravel)
#     33600    0.006    0.000    0.006    0.000 fromnumeric.py:1800(_nonzero_dispatcher)
#     33600    0.021    0.000    0.090    0.000 fromnumeric.py:1804(nonzero)
#     11200    0.003    0.000    0.003    0.000 fromnumeric.py:1899(_shape_dispatcher)
#     11200    0.007    0.000    0.007    0.000 fromnumeric.py:1903(shape)
#     11200    0.002    0.000    0.002    0.000 fromnumeric.py:2232(_any_dispatcher)
#     11200    0.017    0.000    0.181    0.000 fromnumeric.py:2236(any)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:3227(_mean_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:3231(mean)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:3338(_std_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:3343(std)
#     67200    0.048    0.000    0.192    0.000 fromnumeric.py:55(_wrapfunc)
#     11200    0.045    0.000    0.164    0.000 fromnumeric.py:73(_wrapreduction)
#     11200    0.008    0.000    0.008    0.000 fromnumeric.py:74(<dictcomp>)
#     33600    0.007    0.000    0.007    0.000 fromnumeric.py:93(_take_dispatcher)
#     33600    0.034    0.000    0.157    0.000 fromnumeric.py:97(take)
#     33600    0.008    0.000    0.008    0.000 function_base.py:1624(_extract_dispatcher)
#     33600    0.129    0.000    0.915    0.000 function_base.py:1628(extract)
#     33600    0.007    0.000    0.007    0.000 function_base.py:1680(_place_dispatcher)
#     33600    0.033    0.000    0.134    0.000 function_base.py:1684(place)
#     22400    0.178    0.000    0.238    0.000 numerictypes.py:578(_can_coerce_all)
#    156800    0.040    0.000    0.040    0.000 numerictypes.py:587(<listcomp>)
#     11200    0.028    0.000    0.282    0.000 numerictypes.py:602(find_common_type)
#     11200    0.014    0.000    0.014    0.000 numerictypes.py:654(<listcomp>)
#     11200    0.002    0.000    0.002    0.000 numerictypes.py:655(<listcomp>)
#     11200    0.002    0.000    0.002    0.000 shape_base.py:21(_atleast_1d_dispatcher)
#     11200    0.053    0.000    0.150    0.000 shape_base.py:25(atleast_1d)
#         1    0.000    0.000    3.774    3.774 {built-in method builtins.exec}
#     78400    0.021    0.000    0.021    0.000 {built-in method builtins.getattr}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#    112006    0.038    0.000    0.038    0.000 {built-in method builtins.isinstance}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#    190400    0.022    0.000    0.022    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#     22400    0.009    0.000    0.009    0.000 {built-in method builtins.min}
#       400    0.002    0.000    0.002    0.000 {built-in method builtins.sum}
#    201603    0.252    0.000    0.252    0.000 {built-in method numpy.array}
#     33600    0.090    0.000    0.090    0.000 {built-in method numpy.core._multiarray_umath._insert}
# 235202/100802    0.317    0.000    1.585    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#     11200    0.011    0.000    0.011    0.000 {built-in method numpy.zeros}
#         2    0.000    0.000    0.000    0.000 {built-in method time.time}
#     11200    0.027    0.000    0.105    0.000 {method 'any' of 'numpy.generic' objects}
#     34000    0.006    0.000    0.006    0.000 {method 'append' of 'list' objects}
#     22400    0.135    0.000    0.135    0.000 {method 'binomial' of 'numpy.random.mtrand.RandomState' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#     11200    0.003    0.000    0.003    0.000 {method 'items' of 'dict' objects}
#      2400    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#     33600    0.034    0.000    0.034    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#     67200    0.070    0.000    0.070    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#     11203    0.073    0.000    0.073    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#     33600    0.063    0.000    0.063    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#     33600    0.092    0.000    0.092    0.000 {method 'take' of 'numpy.ndarray' objects}

# %%
cProfile.run("simulate(T=6, alpha=1/4, N=100, M=400, score=KG_score)")
# Out:
#          2546714 function calls (2409962 primitive calls) in 3.736 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     11396    0.010    0.000    0.210    0.000 <__array_function__ internals>:2(any)
#     11396    0.011    0.000    0.167    0.000 <__array_function__ internals>:2(atleast_1d)
#     34188    0.036    0.000    1.035    0.000 <__array_function__ internals>:2(extract)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(mean)
#     34188    0.025    0.000    0.139    0.000 <__array_function__ internals>:2(nonzero)
#     34188    0.033    0.000    0.275    0.000 <__array_function__ internals>:2(place)
#     68376    0.051    0.000    0.415    0.000 <__array_function__ internals>:2(ravel)
#     11396    0.014    0.000    0.048    0.000 <__array_function__ internals>:2(shape)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(std)
#     34188    0.027    0.000    0.247    0.000 <__array_function__ internals>:2(take)
#     11200    0.044    0.000    3.408    0.000 <ipython-input-25-1b8dd97bf56d>:1(reward)
#     22400    0.004    0.000    0.004    0.000 <ipython-input-25-1b8dd97bf56d>:15(<lambda>)
#       400    0.027    0.000    3.435    0.009 <ipython-input-25-1b8dd97bf56d>:25(<listcomp>)
#         1    0.076    0.076    3.736    3.736 <ipython-input-25-1b8dd97bf56d>:6(simulate)
#         1    0.000    0.000    0.066    0.066 <ipython-input-25-1b8dd97bf56d>:7(<dictcomp>)
#        49    0.000    0.000    0.033    0.001 <ipython-input-5-a84069e50c30>:12(R1)
#        49    0.000    0.000    0.032    0.001 <ipython-input-5-a84069e50c30>:15(R2)
#        49    0.000    0.000    0.066    0.001 <ipython-input-5-a84069e50c30>:18(KG_score)
#       196    0.001    0.000    0.065    0.000 <ipython-input-5-a84069e50c30>:6(I)
#       196    0.000    0.000    0.001    0.000 <ipython-input-5-a84069e50c30>:9(h)
#         1    0.000    0.000    3.736    3.736 <string>:1(<module>)
#     11396    0.003    0.000    0.003    0.000 <string>:2(_parse_args)
#    102564    0.035    0.000    0.182    0.000 _asarray.py:16(asarray)
#    102567    0.038    0.000    0.134    0.000 _asarray.py:88(asanyarray)
#     11396    0.123    0.000    0.123    0.000 _continuous_distns.py:527(_cdf)
#     11396    0.543    0.000    3.429    0.000 _distn_infrastructure.py:1797(cdf)
#     11396    0.096    0.000    1.522    0.000 _distn_infrastructure.py:520(argsreduce)
#     11396    0.220    0.000    1.256    0.000 _distn_infrastructure.py:545(<listcomp>)
#     11396    0.178    0.000    0.195    0.000 _distn_infrastructure.py:864(_argcheck)
#     22792    0.007    0.000    0.007    0.000 _distn_infrastructure.py:876(_get_support)
#     11396    0.058    0.000    0.062    0.000 _distn_infrastructure.py:901(_open_support_mask)
#         1    0.000    0.000    0.000    0.000 _methods.py:134(_mean)
#         1    0.000    0.000    0.000    0.000 _methods.py:167(_var)
#         1    0.000    0.000    0.000    0.000 _methods.py:215(_std)
#     11396    0.006    0.000    0.076    0.000 _methods.py:44(_any)
#         2    0.000    0.000    0.000    0.000 _methods.py:50(_count_reduce_items)
#     68376    0.011    0.000    0.011    0.000 fromnumeric.py:1689(_ravel_dispatcher)
#     68376    0.084    0.000    0.283    0.000 fromnumeric.py:1693(ravel)
#     34188    0.005    0.000    0.005    0.000 fromnumeric.py:1800(_nonzero_dispatcher)
#     34188    0.020    0.000    0.088    0.000 fromnumeric.py:1804(nonzero)
#     11396    0.002    0.000    0.002    0.000 fromnumeric.py:1899(_shape_dispatcher)
#     11396    0.006    0.000    0.006    0.000 fromnumeric.py:1903(shape)
#     11396    0.002    0.000    0.002    0.000 fromnumeric.py:2232(_any_dispatcher)
#     11396    0.017    0.000    0.176    0.000 fromnumeric.py:2236(any)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:3227(_mean_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:3231(mean)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:3338(_std_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:3343(std)
#     68376    0.046    0.000    0.223    0.000 fromnumeric.py:55(_wrapfunc)
#     11396    0.043    0.000    0.160    0.000 fromnumeric.py:73(_wrapreduction)
#     11396    0.007    0.000    0.007    0.000 fromnumeric.py:74(<dictcomp>)
#     34188    0.006    0.000    0.006    0.000 fromnumeric.py:93(_take_dispatcher)
#     34188    0.035    0.000    0.190    0.000 fromnumeric.py:97(take)
#     34188    0.008    0.000    0.008    0.000 function_base.py:1624(_extract_dispatcher)
#     34188    0.127    0.000    0.928    0.000 function_base.py:1628(extract)
#     34188    0.007    0.000    0.007    0.000 function_base.py:1680(_place_dispatcher)
#     34188    0.032    0.000    0.163    0.000 function_base.py:1684(place)
#     22792    0.169    0.000    0.226    0.000 numerictypes.py:578(_can_coerce_all)
#    159544    0.038    0.000    0.038    0.000 numerictypes.py:587(<listcomp>)
#     11396    0.027    0.000    0.268    0.000 numerictypes.py:602(find_common_type)
#     11396    0.013    0.000    0.013    0.000 numerictypes.py:654(<listcomp>)
#     11396    0.002    0.000    0.002    0.000 numerictypes.py:655(<listcomp>)
#     11396    0.002    0.000    0.002    0.000 shape_base.py:21(_atleast_1d_dispatcher)
#     11396    0.050    0.000    0.144    0.000 shape_base.py:25(atleast_1d)
#         1    0.000    0.000    3.736    3.736 {built-in method builtins.exec}
#     79772    0.020    0.000    0.020    0.000 {built-in method builtins.getattr}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#    113966    0.038    0.000    0.038    0.000 {built-in method builtins.isinstance}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#    193732    0.021    0.000    0.021    0.000 {built-in method builtins.len}
#       197    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#     22400    0.009    0.000    0.009    0.000 {built-in method builtins.min}
#      2400    0.015    0.000    0.020    0.000 {built-in method builtins.sorted}
#       400    0.002    0.000    0.002    0.000 {built-in method builtins.sum}
#    205131    0.243    0.000    0.243    0.000 {built-in method numpy.array}
#     34188    0.121    0.000    0.121    0.000 {built-in method numpy.core._multiarray_umath._insert}
# 239318/102566    0.307    0.000    1.609    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#     11396    0.011    0.000    0.011    0.000 {built-in method numpy.zeros}
#         2    0.000    0.000    0.000    0.000 {built-in method time.time}
#     11396    0.026    0.000    0.102    0.000 {method 'any' of 'numpy.generic' objects}
#     34588    0.006    0.000    0.006    0.000 {method 'append' of 'list' objects}
#     22400    0.128    0.000    0.128    0.000 {method 'binomial' of 'numpy.random.mtrand.RandomState' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#     11396    0.003    0.000    0.003    0.000 {method 'items' of 'dict' objects}
#      2400    0.001    0.000    0.001    0.000 {method 'keys' of 'dict' objects}
#     34188    0.035    0.000    0.035    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#     68376    0.067    0.000    0.067    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#     11399    0.071    0.000    0.071    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#     34188    0.060    0.000    0.060    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#     34188    0.126    0.000    0.126    0.000 {method 'take' of 'numpy.ndarray' objects}
