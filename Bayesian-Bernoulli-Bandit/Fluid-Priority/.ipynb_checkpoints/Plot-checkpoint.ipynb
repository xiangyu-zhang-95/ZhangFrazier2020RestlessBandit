# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
def plot(fname):
    df = pd.read_csv(fname, index_col=0)
    plt.plot(df.loc["opt-gap"], "o-")
    plt.grid()
    plt.show()
plot("fp-20")
plot("fp-15")
